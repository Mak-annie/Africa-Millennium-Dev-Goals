# %% [markdown]
# ### BUSINESS UNDERSTANDING
# Background:
#
# Sustainable Development Goals (SDGs) are a set of global goals adopted by United Nations member states in 2015 to address social, economic, and environmental challenges.
#
# Predicting progress towards SDGs is essential for monitoring development outcomes, guiding policy interventions, and mobilizing resources effectively.
#
#
# Business Problem:
#
# - Lack of reliable methods to forecast progress towards SDGs hinders informed decision-making and targeted interventions.
# - Developing predictive models based on historical data from the Millennium Development Goals (MDGs) era can provide insights into the factors driving successful development outcomes and inform future policy actions.
#
# Business Objectives:
#
# - Develop predictive models to forecast progress towards the Sustainable Development Goals (SDGs) using machine learning techniques.
# - Identify key factors and indicators that contribute to successful development outcomes and progress towards the SDGs.
# - Provide actionable insights and policy recommendations based on the predictive models to support decision-making and resource allocation strategies.

# %% [markdown]
# ### DATA UNDERSTANDING

# %% [markdown]
# ### IMPORTING OF NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### LOADING OF DATASETS

# %%
#load dataset from csv
#data = pd.read_csv('dataset/data/africa_millennium_development_goals_xlsx_1.csv')
#data.head(15)

# %%
#load dataset from excel file
original_data = pd.read_excel('dataset/original/africa-millennium-development-goals-xlsx-1.xlsx')
original_data.head(15)
# Out:
#          CountryName  Country                                      GoalName  \
# 0              Kenya       25                Goal 4: Reduce child mortality
# 1              Kenya       25                Goal 4: Reduce child mortality
# 2              Kenya       25                Goal 4: Reduce child mortality
# 3              Kenya       25                Goal 4: Reduce child mortality
# 4              Kenya       25                Goal 4: Reduce child mortality
# 5              Kenya       25                Goal 4: Reduce child mortality
# 6            Somalia       44               Goal 5: Improve maternal health
# 7            Somalia       44               Goal 5: Improve maternal health
# 8            Somalia       44  Goal 1: Eradicate extreme poverty and hunger
# 9            Somalia       44  Goal 1: Eradicate extreme poverty and hunger
# 10  Congo, Dem. Rep.       12   Goal 7: Ensure environmental sustainability
# 11  Congo, Dem. Rep.       12   Goal 7: Ensure environmental sustainability
# 12  Congo, Dem. Rep.       12   Goal 7: Ensure environmental sustainability
# 13  Congo, Dem. Rep.       12   Goal 7: Ensure environmental sustainability
# 14  Congo, Dem. Rep.       12   Goal 7: Ensure environmental sustainability
#
#           Goal                                      IndicatorName  Indicator  \
# 0   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 1   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 2   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 3   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 4   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 5   KN.1000030         Infant mortality rate per 1000 live births   20267305
# 6   KN.1000040                Contraceptive prevalence rate 15-49   20267705
# 7   KN.1000040                Contraceptive prevalence rate 15-49   20267705
# 8   KN.1000000  Prevalence of underweight children under-five ...   20266005
# 9   KN.1000000  Prevalence of underweight children under-five ...   20266005
# 10  KN.1000060    Carbon dioxide emissions per capita Metric tons   20269405
# 11  KN.1000060    Carbon dioxide emissions per capita Metric tons   20269405
# 12  KN.1000060    Carbon dioxide emissions per capita Metric tons   20269405
# 13  KN.1000060    Carbon dioxide emissions per capita Metric tons   20269405
# 14  KN.1000060    Carbon dioxide emissions per capita Metric tons   20269405
#
#    Social GroupName  Social Group  Units  Scale Frequency        Date   Value
# 0             Women      20136705    NaN      1         A  1990-01-01  123.00
# 1             Women      20136705    NaN      1         A  1992-01-01  107.20
# 2             Women      20136705    NaN      1         A  1996-01-01  108.90
# 3             Women      20136705    NaN      1         A  2000-01-01  110.00
# 4             Women      20136705    NaN      1         A  2001-01-01   95.00
# 5             Women      20136705    NaN      1         A  2007-01-01   70.00
# 6             Women      20136705    NaN      1         A  2000-01-01   11.70
# 7             Women      20136705    NaN      1         A  2007-01-01   14.60
# 8             Women      20136705    NaN      1         A  2005-01-01   26.00
# 9             Women      20136705    NaN      1         A  2007-01-01   36.00
# 10            Total      20137105    NaN      1         A  1990-01-01    1.14
# 11            Total      20137105    NaN      1         A  1991-01-01    1.14
# 12            Total      20137105    NaN      1         A  1992-01-01    1.14
# 13            Total      20137105    NaN      1         A  1993-01-01    1.11
# 14            Total      20137105    NaN      1         A  1998-01-01    0.94

# %%
#performing data exploration
#print("Dimensions of the dataset:",data.shape)
#print("\nFirst few rows of the dataset:")
#data.head()
# Out:
# Dimensions of the dataset: (10610, 13)
#
# First few rows of the dataset:
#   countryname  country                        goalname        goal  \
# 0       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 1       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 2       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 3       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 4       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
#
#                                 indicatorname  indicator social_groupname  \
# 0  Infant mortality rate per 1000 live births   20267305            Women
# 1  Infant mortality rate per 1000 live births   20267305            Women
# 2  Infant mortality rate per 1000 live births   20267305            Women
# 3  Infant mortality rate per 1000 live births   20267305            Women
# 4  Infant mortality rate per 1000 live births   20267305            Women
#
#    social_group  units  scale frequency        date  value
# 0      20136705    NaN   True         A  1990-01-01  123.0
# 1      20136705    NaN   True         A  1992-01-01  107.2
# 2      20136705    NaN   True         A  1996-01-01  108.9
# 3      20136705    NaN   True         A  2000-01-01  110.0
# 4      20136705    NaN   True         A  2001-01-01   95.0

# %%
#performing data exploration
print("Dimensions of the dataset:",original_data.shape)
print("\nFirst few rows of the dataset:")
original_data.head()
# Out:
# Dimensions of the dataset: (10610, 13)
#
# First few rows of the dataset:
#   CountryName  Country                        GoalName        Goal  \
# 0       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 1       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 2       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 3       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
# 4       Kenya       25  Goal 4: Reduce child mortality  KN.1000030
#
#                                 IndicatorName  Indicator Social GroupName  \
# 0  Infant mortality rate per 1000 live births   20267305            Women
# 1  Infant mortality rate per 1000 live births   20267305            Women
# 2  Infant mortality rate per 1000 live births   20267305            Women
# 3  Infant mortality rate per 1000 live births   20267305            Women
# 4  Infant mortality rate per 1000 live births   20267305            Women
#
#    Social Group  Units  Scale Frequency        Date  Value
# 0      20136705    NaN      1         A  1990-01-01  123.0
# 1      20136705    NaN      1         A  1992-01-01  107.2
# 2      20136705    NaN      1         A  1996-01-01  108.9
# 3      20136705    NaN      1         A  2000-01-01  110.0
# 4      20136705    NaN      1         A  2001-01-01   95.0

# %%
#descriptive statistics
print("\nSummary statistics:")
original_data.describe()
# Out:
# Summary statistics:
#             Country     Indicator  Social Group  Units    Scale         Value
# count  10610.000000  1.061000e+04  1.061000e+04    0.0  10610.0  1.061000e+04
# mean      27.962677  2.026766e+07  2.013702e+07    NaN      1.0  6.365211e+03
# std       15.145405  1.734153e+03  1.630599e+02    NaN      0.0  1.298942e+05
# min        1.000000  2.026500e+07  2.013660e+07    NaN      1.0  0.000000e+00
# 25%       14.000000  2.026640e+07  2.013700e+07    NaN      1.0  1.050000e+01
# 50%       30.000000  2.026730e+07  2.013710e+07    NaN      1.0  3.940000e+01
# 75%       39.000000  2.026930e+07  2.013710e+07    NaN      1.0  7.310000e+01
# max       53.000000  2.027070e+07  2.013710e+07    NaN      1.0  4.366048e+06

# %%
#
